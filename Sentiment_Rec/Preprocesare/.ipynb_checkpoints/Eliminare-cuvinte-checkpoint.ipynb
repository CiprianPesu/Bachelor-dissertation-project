# %%
import pandas as pd
from tqdm import tqdm
from nltk.tokenize import RegexpTokenizer

# %%
dataframe = pd.read_csv('../Datasets/Stem/validity-punct-stop-stem.csv')
dataframe.head()
# Out:
#    sentiment                                               text
# 0          0  cd horribl wish could take back best buy letoy...
# 1          0  there no thing either get nothingand laptop te...
# 2          0  love layout eas use lock time give usb error i...
# 3          0  signific proport book dedic produc well presen...
# 4          0  qualiti dvd made imposs watch way return handl...

# %%
dataframe=dataframe.dropna()
dataframe.count()
# Out:
# sentiment    400000
# text         400000
# dtype: int64

# %%
dataframe["text"]=dataframe["text"].str.lower()
dataframe.head()
# Out:
#    sentiment                                               text
# 0          0  cd horribl wish could take back best buy letoy...
# 1          0  there no thing either get nothingand laptop te...
# 2          0  love layout eas use lock time give usb error i...
# 3          0  signific proport book dedic produc well presen...
# 4          0  qualiti dvd made imposs watch way return handl...

# %%
dataframe.count()
# Out:
# sentiment    400000
# text         400000
# dtype: int64

# %%
tokenizer = RegexpTokenizer(r'\w+')
word_info = {} # { "word" : [id,  numar_de_aparitii_in_exemple_pozitive, numar_de_aparitii_in_exemple_negative]}

for i, row in tqdm(dataframe.iterrows(), total=len(dataframe)):
  review = row['text']
  tokens = tokenizer.tokenize(review)

  for tok in tokens:
    if tok not in word_info:
      word_info[tok] = [-1, 0, 0] # [id,  numar_de_aparitii_in_exemple_pozitive, numar_de_aparitii_in_exemple_negative]

    if row['sentiment'] == 2:
      word_info[tok][1] += 1
    else:
      word_info[tok][2] += 1

print(len(word_info))
# Out:
#  17%|█████▊                            | 68904/400000 [00:12<00:58, 5627.88it/s]

# %%
to_be_deleted = []

for word in word_info:
  pos_appearances = word_info[word][1]
  neg_appearances = word_info[word][2]
  total_appearances = pos_appearances + neg_appearances

  if total_appearances < 1000: 
    to_be_deleted.append(word)

for elem in to_be_deleted:
  del word_info[elem]

print(len(word_info))
# Out:
# 9585

# %%
print(len(word_info))
# Out:
# 9585

# %%
def clean_df(a):
    a_token=a.lower().split()
    
    str1=""
    for tk in a_token:
        if tk not in word_info.keys():
            continue
        else:
            str1 += tk+" "
            
    return str1

# %%
dataframe['text'] = dataframe['text'].apply(lambda x: clean_df(x))

# %%
dataframe=dataframe.dropna()
dataframe.count()
# Out:
# sentiment    400000
# text         400000
# dtype: int64

# %%
dataframe.count()
# Out:
# sentiment    400000
# text         400000
# dtype: int64

# %%
dataframe.head()
dataframe.to_csv("../Datasets/Stem-Cuvinte-Eliminate/validity-punct-stop-1000.csv",index=False)

# %%
dataframe.head()
# Out:
#    sentiment                                               text
# 0          0  cd horrible wish could take back best buy buy ...
# 1          0  theres no thing either get laptop tells differ...
# 2          0  loved layout ease use locked time giving usb e...
# 3          0  significant book dedicated producing well pres...
# 4          0  quality dvd made impossible watch way return h...

# %%
print(word_info.keys())
# Out:
# dict_keys(['sound', 'track', 'beautiful', 'paints', 'mind', 'well', 'would', 'recomend', 'even', 'people', 'hate', 'game', 'music', 'played', 'cross', 'games', 'ever', 'best', 'backs', 'away', 'crude', 'takes', 'step', 'grate', 'guitars', 'soulful', 'impress', 'anyone', 'cares', 'listen', 'im', 'reading', 'lot', 'reviews', 'saying', 'soundtrack', 'figured', 'id', 'write', 'review', 'disagree', 'bit', 'ultimate', 'masterpiece', 'timeless', 'listening', 'years', 'beauty', 'simply', 'refuses', 'price', 'tag', 'pretty', 'must', 'say', 'going', 'buy', 'cd', 'much', 'money', 'one', 'feel', 'worth', 'every', 'penny', 'favorite', 'time', 'hands', 'intense', 'sadness', 'fate', 'means', 'youve', 'hope', 'distant', 'promise', 'girl', 'stole', 'star', 'important', 'inspiration', 'personally', 'throughout', 'teen', 'higher', 'energy', 'tracks', 'like', 'times', 'trigger', 'absolutely', 'superb', 'amazing', 'probably', 'composers', 'work', 'havent', 'heard', 'cant', 'sure', 'never', 'twice', 'iti', 'wish', 'could', 'give', '6', 'stars', 'truly', 'enjoy', 'video', 'relaxing', 'disk', 'favorites', 'life', 'death', 'forest', 'illusion', 'ancient', 'dragons', 'lost', 'two', 'home', 'girlfriend', 'likes', 'three', 'garden', 'god', 'sea', 'burning', 'prayer', 'tower', 'dragon', 'radical', 'excellent', 'brought', 'know', 'divine', 'single', 'song', 'tells', 'story', 'good', 'greatest', 'songs', 'without', 'doubt', 'magical', 'wind', 'jewel', 'translation', 'perfect', 'ask', 'poured', 'heart', 'wrote', 'paper', 'quite', 'actually', 'taking', 'read', 'least', 'whether', 'aware', 'not', 'contributed', 'greatly', 'mood', 'minute', 'whole', '3', 'cds', 'exact', 'count', 'remarkable', 'assure', 'forget', 'everything', 'listener', 'fastpaced', 'energetic', 'dancing', 'slower', 'haunting', 'purely', 'beautifully', 'composed', 'fantastic', 'vocals', 'soundtracks', 'surely', 'loved', 'wicked', 'saints', 'pleasantly', 'surprised', 'changes', 'book', 'someone', 'romance', 'novels', 'world', 'raving', 'bought', 'brilliant', 'true', 'wonderful', 'told', 'friends', 'typical', 'crime', 'becuase', 'missing', 'warming', 'finished', 'fell', 'love', 'expected', 'average', 'instead', 'found', 'books', 'thought', 'predict', 'outcome', 'shocked', 'writting', 'descriptive', 'broke', 'felt', 'reader', 'lover', 'dont', 'let', 'cover', 'fool', 'spectacular', 'easy', 'made', 'want', 'keep', 'put', 'left', 'wanting', 'follow', 'coming', 'soon', 'used', 'gotten', 'enjoyable', 'great', 'booki', 'fast', 'enough', 'boy', 'twist', 'turns', 'keeps', 'guessing', 'happen', 'next', 'makes', 'fall', 'heat', 'also', 'make', 'go', 'several', 'emotions', 'quick', 'something', 'end', 'day', 'night', 'yet', 'realistic', 'showed', 'error', 'human', 'fact', 'writer', 'loving', 'side', 'twisted', 'turned', 'glass', 'castle', 'hear', 'folks', 'em', 'anymore', 'might', 'talking', 'cool', 'young', 'cuban', 'searching', 'resort', 'kitchen', 'gig', 'zen', 'motorcycle', 'maintenance', 'man', 'hysterical', 'italian', 'chefs', 'right', 'handed', 'pitcher', 'plays', 'team', 'owner', 'often', 'case', 'finds', 'honest', 'comical', 'always', 'emotional', 'interaction', 'players', 'mix', 'special', 'effects', 'salsa', 'flashbacks', 'gets', '4', 'big', 'doctor', 'required', 'wear', 'compression', 'wore', 'ugly', 'white', 'ted', 'hose', 'thick', 'brown', 'gave', 'needed', 'looked', 'regular', 'though', 'blood', 'gone', 'still', 'support', 'legs', 'problems', 'tops', 'rolling', 'tried', 'adhesive', 'hated', 'skin', 'pulled', 'inexpensive', 'belt', 'works', 'fine', 'helps', 'product', 'however', 'difficult', 'get', 'older', 'ive', 'full', 'workout', 'getting', 'wears', 'begin', 'roll', 'top', 'create', 'deep', 'difficulties', 'addressed', 'help', 'funny', 'knowing', 'quickly', 'packaged', 'cookies', 'no', 'cookie', 'guess', 'noticed', 'since', 'first', 'baking', 'convenience', 'dough', 'wrapped', 'plastic', 'surprise', 'mixing', 'messy', 'extremely', 'sticky', 'flexibility', 'ratio', 'ingredients', 'add', 'ext ...

# %%
import pickle

# %%
with open("../Datasets/Stem-Cuvinte-Eliminate/cuvinte.pkl", "wb") as pkl_handle:
	pickle.dump(word_info, pkl_handle)

# %%
with open("../Datasets/Stem-Cuvinte-Eliminate/cuvinte.pkl", "rb") as pkl_handle:
	output = pickle.load(pkl_handle)

# %%
print(len(output.keys()))
# Out:
# 9585
