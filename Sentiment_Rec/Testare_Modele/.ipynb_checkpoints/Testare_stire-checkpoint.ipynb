# %%
import pandas as pd
import string
import numpy as np
import glob
from keras.preprocessing.sequence import pad_sequences
from nltk.stem import PorterStemmer

# %%
porter=PorterStemmer()
stopwords=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y']
import pickle
with open('tokenizer-200.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
def clean_punct(a):        
    return a.lower().translate(str.maketrans('', '', string.punctuation))

def clean_stop(a):
    a_token=a.split()
    
    str1=""
    for tk in a_token:
        if tk in stopwords:
            continue
        else:
            str1 += tk+" "
            
    return str1

def clean_stem(a):
    a_token=a.split()
    
    str1=""
    for tk in a_token:
            str1 += porter.stem(tk)+" "
            
    return str1

# %%
count=0;

results1=[]
results2=[]

pozitive_total=0
negative_total=0
pozitive_corecte=0
negative_corecte=0
neutre_total=0
neutre_corecte=0
txtfiles = []
for file in glob.glob("Stiri_pozitive/*.txt"):
    txtfiles.append(file)
    
from tensorflow import keras
model = keras.models.load_model('./Model-200/')    

print("Model 1")
print("")

print("---Stiri Pozitive---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        for i in range(0,len(paragrafe)):
            sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
            sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        
        print(str(file)+"  "+str(sum_neg/len(paragrafe))+"     "+str(sum_poz/len(paragrafe)))
        results1.append([sum_neg/len(paragrafe),sum_poz/len(paragrafe)])
        pozitive_total+=1
        if sum_neg < sum_poz:
            pozitive_corecte+=1

     
print("Total stiri pozitive : "+str(pozitive_total))
print("Corecte stiri pozitive : "+str(pozitive_corecte)) 
print("Acuratete Pozitive: "+str(pozitive_corecte/pozitive_total))
print("")    


from tensorflow import keras
model = keras.models.load_model('./Model-200/')

txtfiles = []
for file in glob.glob("Stiri_negative/*.txt"):
    txtfiles.append(file)
print("---Stiri Negative---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        nr_paragrafe=0
        for i in range(0,len(paragrafe)):
            #if results[i][0] - results[i][1] < 0.1 or results[i][1] - results[i][0] > -0.1 :
                nr_paragrafe+=1*len(str(paragrafe[i]).split())
                sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
                sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        print(str(file)+"  "+str(sum_neg/nr_paragrafe)+"     "+str(sum_poz/nr_paragrafe))
        
        results1.append([sum_neg/nr_paragrafe,sum_poz/nr_paragrafe])
        
        negative_total+=1
        if sum_neg > sum_poz:
            negative_corecte+=1
    
print("Total stiri negative : "+str(negative_total))
print("Corecte stiri negative : "+str(negative_corecte)) 
print("Acuratete negative: "+str(negative_corecte/negative_total))

print("")
print("Total stiri :" + str(pozitive_total+negative_total+neutre_total))
print("Total corecte :" + str(pozitive_corecte+negative_corecte+neutre_corecte))
print("Acuratete :" + str((pozitive_corecte+negative_corecte+neutre_corecte)/(pozitive_total+negative_total+neutre_total)))
    

print("Model 2")
print("")

from tensorflow import keras
model = keras.models.load_model('./Model-200-2/')

pozitive_total=0
negative_total=0
pozitive_corecte=0
negative_corecte=0
neutre_total=0
neutre_corecte=0

txtfiles = []
for file in glob.glob("Stiri_pozitive/*.txt"):
    txtfiles.append(file)

print("---Stiri Pozitive---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        nr_paragrafe=0
        for i in range(0,len(paragrafe)):
            nr_paragrafe+=1*len(str(paragrafe[i]).split())
            sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
            sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        
        print(str(file)+"  "+str(sum_neg/len(paragrafe))+"     "+str(sum_poz/len(paragrafe)))
        results2.append([sum_neg/nr_paragrafe,sum_poz/nr_paragrafe])
        pozitive_total+=1
        if sum_neg < sum_poz:
            pozitive_corecte+=1

     
print("Total stiri pozitive : "+str(pozitive_total))
print("Corecte stiri pozitive : "+str(pozitive_corecte)) 
print("Acuratete Pozitive: "+str(pozitive_corecte/pozitive_total))
print("")    


txtfiles = []
for file in glob.glob("Stiri_negative/*.txt"):
    txtfiles.append(file)
print("---Stiri Negative---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        nr_paragrafe=0
        for i in range(0,len(paragrafe)):
            #if results[i][0] - results[i][1] < 0.1 or results[i][1] - results[i][0] > -0.1 :
                nr_paragrafe+=1*len(str(paragrafe[i]).split())
                sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
                sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        print(str(file)+"  "+str(sum_neg/nr_paragrafe)+"     "+str(sum_poz/nr_paragrafe))
        results2.append([sum_neg/nr_paragrafe,sum_poz/nr_paragrafe])
        negative_total+=1
        if sum_neg > sum_poz:
            negative_corecte+=1
    
print("Total stiri negative : "+str(negative_total))
print("Corecte stiri negative : "+str(negative_corecte)) 
print("Acuratete negative: "+str(negative_corecte/negative_total))

print("")
print("Total stiri :" + str(pozitive_total+negative_total+neutre_total))
print("Total corecte :" + str(pozitive_corecte+negative_corecte+neutre_corecte))

print("Acuratete :" + str((pozitive_corecte+negative_corecte+neutre_corecte)/(pozitive_total+negative_total+neutre_total)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model 1
#
# ---Stiri Pozitive---
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 128).
# Stiri_pozitive/12.txt  4.421536915661657     17.990227748365964
# Stiri_pozitive/11.txt  9.602742195129395     11.647258123382926
# Stiri_pozitive/31.txt  6.672369552405413     21.883186020233012
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (32, 128).
# Stiri_pozitive/3.txt  5.635587509808829     13.645662499475293
# Stiri_pozitive/17.txt  9.281530902617508     12.385135788056585
# Stiri_pozitive/8.txt  5.924315747272756     12.456636501919656
# Stiri_pozitive/10.txt  8.167308569028974     7.592691170275211
# Stiri_pozitive/16.txt  5.200274874352747     8.133058332139626
# Stiri_pozitive/23.txt  10.416889565597687     16.868824953479425
# Stiri_pozitive/33.txt  1.3411201743098597     17.15887988607089
# Stiri_pozitive/30.txt  10.638329294429202     24.44862715219674
# Stiri_pozitive/18.txt  7.299610589586553     9.319437091194448
# Stiri_pozitive/7.txt  10.969411552113552     18.799819269647394
# Stiri_pozitive/22.txt  3.2026876075459376     11.297312457646642
# Stiri_pozitive/6.txt  6.585818679634637     10.289181345297644
# Stiri_pozitive/29.txt  7.025980442762375     27.974020183086395
# Stiri_pozitive/26.txt  10.166787369254356     14.333212268849215
# Stiri_pozitive/27.txt  4.862495261140996     11.915282474623787
# Stiri_pozitive/28.txt  2.9471498854303113     24.386183343827724
# Stiri_pozitive/0.txt  2.3580602668225765     11.308606574932734
# Stiri_pozitive/1.txt  8.466879867948592     10.783120179176331
# Stiri_pozitive/21.txt  16.94632988480421     10.13059324112076
# Stiri_pozitive/9.txt  6.112283165118209     11.035864884378734
# Stiri_pozitive/24.txt  9.37156591605809     11.73954544464747
# Stiri_pozitive/13.txt  6.501630105506629     14.758369966596366
# Stiri_pozitive/14.txt  6.093619963377714     8.906380096375942
# Stiri_pozitive/2.txt  5.570715352271994     22.429284433523815
# Stiri_pozitive/25.txt  7.382721253577619     14.31727883219719
# Stiri_pozitive/5.txt  7.546786963751421     15.623425902838402
# Stiri_pozitive/32.txt  8.864448638395311     16.74779611799334
# Stiri_pozitive/4.txt  3.98828572700559     12.419121637388512
# Stiri_pozitive/20.txt  5.257254581451416     12.582745568156243
# Stiri_pozitive/19.txt  8.362382447347045     25.18761750641279
# Stiri_pozitive/15.txt  6.4753132639452815     10.370840665526115
# Total stiri pozitive : 34
# Corecte stiri pozitive : 32
# Acuratete Pozitive: 0.9411764705882353
#
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ---Stiri Negative---
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 128).
# Stiri_negative/12.txt  0.22064173524081707     0.7793582525253296
# Stiri_negative/11.txt  0.47821282416582106     0.5217871587144004
# Stiri_negative/31.txt  0.2638216190052167     0.736178390030722
# Stiri_negative/3.txt  0.4532082519789999     0.5467917541816869
# Stiri_negative/17.txt  0.3377695341892675     0.6622304731993367
# Stiri_negative/8.txt  0.38244571495164453     0.617554276760462
# Stiri_negative/10.txt  0.6955451007749214     0.30445489169307094
# Stiri_negative/16.txt  0.5714381095803274     0.4285618967170383
# Stiri_negative/23.txt  0.6367390780399244     0.36326092411763966
# Stiri_negative/33.txt  0.5269328060426882     0.4730671988356681
# Stiri_negative/30.txt  0.4793250321641437     0.5206749648866682
# Stiri_negative/18.txt  0.47158537142467305     0.5284146186106843
# Stiri_negative/7.txt  0.4367689190099422     0.5632310936150593
# Stiri_negative/22.txt  0.4964888731991579     0.5035111151900388
# Stiri_negative/6.txt  0.7069702963371062     0.29302970715666893
# Stiri_negative/29.txt  0.4983952002287025     0.5016047781660357
# Stiri_negative/26.txt  0.5009690787410364     0.4990309259155765
# Stiri_negative/27.txt  0.45658889025657196     0.543411116277812
# Stiri_negative/28.txt  0.6130526571401528     0.38694734131464537
# Stiri_negative/0.txt  0.44178872471544106     0.5582112578823812
# Stiri_negative/1.txt  0.7016219716155674     0.29837804626885467
# Stiri_negative/21.txt  0.6048393436305896     0.3951606657687063
# Stiri_negative/9.txt  0.5699871485965364     0.4300128382899417
# Stiri_negative/24.txt  0.5340140191838145     0.46598598547279835
# Stiri_negative/13.txt  0.4422643304676623     0.5577356462140342
# Stiri_negative/14.txt  0.6073869130741327     0.3926130891483054
# Stiri_negative/2.txt  0.6199419747201212     0.38005802873522043
# Stiri_negative/25.txt  0.33921626216500117     0.6607837370176356
# Stiri_negative/5.txt  0.6769888403915589     0.32301115047547124
# Stiri_negative/32.txt  0.23715693782013592     0.7628430733757634
# Stiri_negative/4.txt  0.47341259313600786     0.5265874063198486
# Stiri_negative/20.txt  0.712285807851144     0.28771417763912016
# Stiri_negative/19.txt  0.4339619584773716     0.5660380430911717
# Stiri_negative/15.txt  0.2711116601704875     0.7288883333118799
# Total stiri negative : 34
# Corecte stiri negative : 15
# Acuratete negative: 0.4411764705882353
#
# Total stiri :68
# Total corecte :47
# Acuratete :0.6911764705882353
# Model 2
#
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ---Stiri Pozitive---
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 128).
# Stiri_pozitive/12.txt  10.584568717023906     11.827195915667449
# Stiri_pozitive/11.txt  12.603514209389687     8.646485402947292
# Stiri_pozitive/31.txt  11.330898977557403     17.224656677356474
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (32, 128).
# Stiri_pozitive/3.txt  8.339178033580538     10.942071755038342
# Stiri_pozitive/17.txt  13.728502411809233     7.938164563642608
# Stiri_pozitive/8.txt  7.882934375266943     10.498018071410202
# Stiri_pozitive/10.txt  11.128443739116191     4.631556169725955
# Stiri_pozitive/16.txt  8.386969210373032     4.946364265294203
# Stiri_pozitive/23.txt  14.261589129588433     13.024125646799803
# Stiri_pozitive/33.txt  1.6637457242856424     16.83625461657842
# Stiri_pozitive/30.txt  14.663372854904637     20.423583284546822
# Stiri_pozitive/18.txt  10.870011113938832     5.749036408162543
# Stiri_pozitive/7.txt  17.29539884863278     12.473831681682405
# Stiri_pozitive/22.txt  6.5938184994405935     7.906181551516056
# Stiri_pozitive/6.txt  8.974556770912992     7.900443023769185
# Stiri_pozitive/29.txt  23.779586374759674     11.220412582159042
# Stiri_pozitive/26.txt  12.557193808956072     11.942806319294808
# Stiri_pozitive/27.txt  8.137708437111643     8.640069329076344
# Stiri_pozitive/28.txt  4.721502943973367     22.611830724403262
# Stiri_pozitive/0.txt  5.637331634759903     8.029335051774979
# Stiri_pozitive/1.txt  12.668309811875224     6.5816900918260215
# Stiri_pozitive/21.txt  22.250765126485092     4.826157937739761
# Stiri_pozitive/9.txt  9.713258336263674     7.434889735084855
# Stiri_pozitive/24.txt  13.515435631076494     7.595675763156679
# Stiri_pozitive/13.txt  10.470850835032762     10.789149113912135
# Stiri_pozitive/14.txt  8.636188276037574     6.36381172163412
# Stiri_pozitive/2.txt  8.376802479848266     19.6231980000933
# Stiri_pozitive/25.txt  9.6823264549952     12.017673732340336
# Stiri_pozitive/5.txt  11.811577837716074     11.35863492621525
# Stiri_pozitive/32.txt  12.07014958341891     13.54209528889089
# Stiri_pozitive/4.txt  8.127588034228042     8.279819277701554
# Stiri_pozitive/20.txt  8.587508668601513     9.252491408623754
# Stiri_pozitive/19.txt  11.717833249364048     21.832166815397795
# Stiri_pozitive/15.txt  9.69649826334073     7.149655575577456
# Total stiri pozitive : 34
# Corecte stiri pozitive : 17
# Acuratete Pozitive: 0.5
#
# ---Stiri Negative---
# Stiri_negative/12.txt  0.45332171687483785     0.5466782817840576
# Stiri_negative/11.txt  0.7089564989672766     0.2910435139636199
# Stiri_negative/31.txt  0.39545083504688583     0.604549159015556
# Stiri_negative/3.txt  0.6152051808914165     0.38479482459063213
# Stiri_negative/17.txt  0.564602966400252     0.4353970520787959
# Stiri_negative/8.txt  0.5929798821932455     0.4070201163301758
# Stiri_negative/10.txt  0.883548223255762     0.11645178740101109
# Stiri_negative/16.txt  0.7293755994397122     0.2706244126614261
# Stiri_negative/23.txt  0.8130293364326159     0.18697066870712054
# Stiri_negative/33.txt  0.6652778440288135     0.3347221522458962
# Stiri_negative/30.txt  0.6549301222285144     0.3450698820139285
# Stiri_negative/18.txt  0.6785743279698117     0.3214256742796123
# Stiri_negative/7.txt  0.579318013020255     0.4206819818217915
# Stiri_negative/22.txt  0.7669228956027685     0.23307711164925607
# Stiri_negative/6.txt  0.8337573883897167     0.16624262422786257
# Stiri_negative/29.txt  0.5552598357428121     0.44474016323699866
# Stiri_negative/26.txt  0.663361192739103     0.33663879259256646
# Stiri_negative/27.txt  0.6569245324887145     0.3430754642829887
# Stiri_negative/28.txt  0.770069187880496     0.2299308217811004
# Stiri_negative/0.txt  0.6316925428562881     0.36830746346183924
# Stiri_negative/1.txt  0.8200403953470835     0.17995961017175993
# Stiri_negative/21.txt  0.7497274404594684     0.2502725765745829
# Stiri_negative/9.txt  0.7057759573795651     0.29422404437057126
# Stiri_negative/24.txt  0.8294113045558333     0.1705887170683127
# Stiri_negative/13.txt  0.6212254566920771     0.37877454165167906
# Stiri_negative/14.txt  0.8032575812286291     0.19674241872599874
# Stiri_negative/2.txt  0.7889819653110876     0.21101804926107381
# Stiri_negative/25.txt  0.553399932692574     0.4466000662071292
# Stiri_negative/5.txt  0.8819861544716743     0.11801384803388387
# Stiri_negative/32.txt  0.5971011424096682     0.4028988611153377
# Stiri_negative/4.txt  0.6362557038664818     0.36374430992546375
# Stiri_negative/20.txt  0.8548600394368747     0.14513995084553902
# Stiri_negative/19.txt  0.6152260411754811     0.38477396109330475
# Stiri_negative/15.txt  0.4149750741019871     0.5850249254006574
# Total stiri negative : 34
# Corecte stiri negative : 31
# Acuratete negative: 0.9117647058823529
#
# Total stiri :68
# Total corecte :48
# Acuratete :0.7058823529411765

# %%
count=0
nr_pozitive=0
nr_negativ=0

txtfiles=[]
for file in glob.glob("Stiri_pozitive/*.txt"):
    txtfiles.append(file)
total_poz=len(txtfiles)
    
for file in glob.glob("Stiri_negative/*.txt"):
    txtfiles.append(file)    

total_neg=len(txtfiles)-total_poz
    
print(total_poz)
print(total_neg)
print("")
print(len(results1))
print(len(results2))
print("")
for i in range(len(txtfiles)):
    print(txtfiles[i],end="")
    
    if i<total_poz:
        if results1[i][0]<results1[i][1] and results2[i][0]<results2[i][1]:
            print("--- Pozitiv")
            nr_pozitive+=1
        elif results1[i][0]>results1[i][1] and results2[i][0]>results2[i][1]:
            print("--- Negativ")
        elif results1[i][0]*0.80+results2[i][0]*0.20<results2[i][1]*0.20+results1[i][1]*0.80:
            print("--- Pozitiv")
            nr_pozitive+=1
        elif results1[i][0]*0.80+results2[i][0]*0.20>results2[i][1]*0.20+results1[i][1]*0.80:
            print("--- Negativ")
        else:
            print("")
    else:
        if results1[i][0]<results1[i][1] and results2[i][0]<results2[i][1]:
            print("--- Pozitiv")
        elif results1[i][0]>results1[i][1] and results2[i][0]>results2[i][1]:
            print("--- Negativ")
            nr_negativ+=1
        elif results1[i][0]*0.80+results2[i][0]*0.20<results2[i][1]*0.20+results1[i][1]*0.80:
            print("--- Pozitiv")
        elif results1[i][0]*0.80+results2[i][0]*0.20>results2[i][1]*0.20+results1[i][1]*0.80:
            print("--- Negativ")
            nr_negativ+=1
        else:
            print("")
    
    if i == total_poz:
        print("")
        print("")

print(nr_pozitive)
print(nr_negativ)

print("")
print((nr_pozitive+nr_negativ)/len(results2))
# Out:
# 34
# 34
#
# 68
# 68
#
# Stiri_pozitive/12.txt--- Pozitiv
# Stiri_pozitive/11.txt--- Pozitiv
# Stiri_pozitive/31.txt--- Pozitiv
# Stiri_pozitive/3.txt--- Pozitiv
# Stiri_pozitive/17.txt--- Pozitiv
# Stiri_pozitive/8.txt--- Pozitiv
# Stiri_pozitive/10.txt--- Negativ
# Stiri_pozitive/16.txt--- Pozitiv
# Stiri_pozitive/23.txt--- Pozitiv
# Stiri_pozitive/33.txt--- Pozitiv
# Stiri_pozitive/30.txt--- Pozitiv
# Stiri_pozitive/18.txt--- Pozitiv
# Stiri_pozitive/7.txt--- Pozitiv
# Stiri_pozitive/22.txt--- Pozitiv
# Stiri_pozitive/6.txt--- Pozitiv
# Stiri_pozitive/29.txt--- Pozitiv
# Stiri_pozitive/26.txt--- Pozitiv
# Stiri_pozitive/27.txt--- Pozitiv
# Stiri_pozitive/28.txt--- Pozitiv
# Stiri_pozitive/0.txt--- Pozitiv
# Stiri_pozitive/1.txt--- Pozitiv
# Stiri_pozitive/21.txt--- Negativ
# Stiri_pozitive/9.txt--- Pozitiv
# Stiri_pozitive/24.txt--- Pozitiv
# Stiri_pozitive/13.txt--- Pozitiv
# Stiri_pozitive/14.txt--- Pozitiv
# Stiri_pozitive/2.txt--- Pozitiv
# Stiri_pozitive/25.txt--- Pozitiv
# Stiri_pozitive/5.txt--- Pozitiv
# Stiri_pozitive/32.txt--- Pozitiv
# Stiri_pozitive/4.txt--- Pozitiv
# Stiri_pozitive/20.txt--- Pozitiv
# Stiri_pozitive/19.txt--- Pozitiv
# Stiri_pozitive/15.txt--- Pozitiv
# Stiri_negative/12.txt--- Pozitiv
#
#
# Stiri_negative/11.txt--- Negativ
# Stiri_negative/31.txt--- Pozitiv
# Stiri_negative/3.txt--- Pozitiv
# Stiri_negative/17.txt--- Pozitiv
# Stiri_negative/8.txt--- Pozitiv
# Stiri_negative/10.txt--- Negativ
# Stiri_negative/16.txt--- Negativ
# Stiri_negative/23.txt--- Negativ
# Stiri_negative/33.txt--- Negativ
# Stiri_negative/30.txt--- Negativ
# Stiri_negative/18.txt--- Negativ
# Stiri_negative/7.txt--- Pozitiv
# Stiri_negative/22.txt--- Negativ
# Stiri_negative/6.txt--- Negativ
# Stiri_negative/29.txt--- Negativ
# Stiri_negative/26.txt--- Negativ
# Stiri_negative/27.txt--- Pozitiv
# Stiri_negative/28.txt--- Negativ
# Stiri_negative/0.txt--- Pozitiv
# Stiri_negative/1.txt--- Negativ
# Stiri_negative/21.txt--- Negativ
# Stiri_negative/9.txt--- Negativ
# Stiri_negative/24.txt--- Negativ
# Stiri_negative/13.txt--- Pozitiv
# Stiri_negative/14.txt--- Negativ
# Stiri_negative/2.txt--- Negativ
# Stiri_negative/25.txt--- Pozitiv
# Stiri_negative/5.txt--- Negativ
# Stiri_negative/32.txt--- Pozitiv
# Stiri_negative/4.txt--- Negativ
# Stiri_negative/20.txt--- Negativ
# Stiri_negative/19.txt--- Pozitiv
# Stiri_negative/15.txt--- Pozitiv
# 32
# 21
#
# 0.7794117647058824

# %%
from tensorflow import keras
model = keras.models.load_model('./Model-200-3/')

count=0;

pozitive_total=0
negative_total=0
pozitive_corecte=0
negative_corecte=0
neutre_total=0
neutre_corecte=0
txtfiles = []
for file in glob.glob("Stiri_pozitive/*.txt"):
    txtfiles.append(file)
    

print("---Stiri Pozitive---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        nr_paragrafe=0
        for i in range(0,len(paragrafe)):
            if np.count_nonzero(X_train[i]) > 1:
                nr_paragrafe+=1*len(str(paragrafe[i]).split())
                sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
                sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        
        print(str(file)+"  "+str(sum_neg/nr_paragrafe)+"     "+str(sum_poz/nr_paragrafe))
        
        pozitive_total+=1
        if sum_neg < sum_poz:
            pozitive_corecte+=1

     
print("Total stiri pozitive : "+str(pozitive_total))
print("Corecte stiri pozitive : "+str(pozitive_corecte)) 
print("Acuratete Pozitive: "+str(pozitive_corecte/pozitive_total))
print("")    

txtfiles = []
for file in glob.glob("Stiri_negative/*.txt"):
    txtfiles.append(file)
print("---Stiri Negative---")    
for file in txtfiles:
    with open(file, "r") as fis:
        stire = fis.read()
        
        paragrafe=str(stire).split('\n')
        while("" in paragrafe) :
            paragrafe.remove("")
            
        paragrafe=list(map(clean_punct, paragrafe))
        paragrafe=list(map(clean_stop, paragrafe))
        #paragrafe=list(map(clean_stem, paragrafe))
        
        X_train = tokenizer.texts_to_sequences(paragrafe)
        X_train = pad_sequences(X_train, maxlen = 128)
        
        results=model.predict(X_train)
        
        sum_poz=0
        sum_neg=0
        nr_paragrafe=0
        for i in range(0,len(paragrafe)):
                nr_paragrafe+=1*len(str(paragrafe[i]).split())
                sum_neg+=results[i][0]*len(str(paragrafe[i]).split())
                sum_poz+=results[i][1]*len(str(paragrafe[i]).split())
        print(str(file)+"  "+str(sum_neg/nr_paragrafe)+"     "+str(sum_poz/nr_paragrafe))
        
        negative_total+=1
        if sum_neg > sum_poz:
            negative_corecte+=1
    
print("Total stiri negative : "+str(negative_total))
print("Corecte stiri negative : "+str(negative_corecte)) 
print("Acuratete negative: "+str(negative_corecte/negative_total))

print("")
print("Total stiri :" + str(pozitive_total+negative_total+neutre_total))
print("Total corecte :" + str(pozitive_corecte+negative_corecte+neutre_corecte))
print("Acuratete :" + str((pozitive_corecte+negative_corecte+neutre_corecte)/(pozitive_total+negative_total+neutre_total)))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ---Stiri Pozitive---
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None, 128).
# Stiri_pozitive/34.txt  0.420916145861681     0.5790838526189327
# Stiri_pozitive/12.txt  0.2769347043420644     0.723065297575073
# Stiri_pozitive/11.txt  0.5058651545468499     0.494134851523182
# Stiri_pozitive/31.txt  0.31195743682319504     0.6880425607792868
# WARNING:tensorflow:Model was constructed with shape (None, 209) for input KerasTensor(type_spec=TensorSpec(shape=(None, 209), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (32, 128).
# Stiri_pozitive/3.txt  0.35982747486389033     0.6401725329780278
# Stiri_pozitive/17.txt  0.4975405743488899     0.5024594175509918
# Stiri_pozitive/8.txt  0.3705979769595855     0.6294020015958677
# Stiri_pozitive/10.txt  0.6323536083310237     0.36764638441695174
# Stiri_pozitive/16.txt  0.4683595075563811     0.5316405038043552
# Stiri_pozitive/23.txt  0.4740646847119038     0.5259353165753693
# Stiri_pozitive/33.txt  0.06629338419182343     0.9337066164961806
# Stiri_pozitive/30.txt  0.33343315650267696     0.6665668416549998
# Stiri_pozitive/18.txt  0.512315908572541     0.487684074669115
# Stiri_pozitive/7.txt  0.45827708692946867     0.5417229260278273
# Stiri_pozitive/22.txt  0.25727390389268595     0.742726125754416
# Stiri_pozitive/6.txt  0.48952002026945224     0.5104799805079946
# Stiri_pozitive/29.txt  0.3976344755717686     0.6023655761565481
# Stiri_pozitive/26.txt  0.4848109235492896     0.5151891013810119
# Stiri_pozitive/27.txt  0.3394661461379354     0.6605338389609033
# Stiri_pozitive/28.txt  0.19998365734624335     0.8000163518619247
# Stiri_pozitive/0.txt  0.23127126175819374     0.7687287476004624
# Stiri_pozitive/1.txt  0.5797901774511014     0.42020982566141274
# Stiri_pozitive/21.txt  0.7301909266547724     0.26980907391407527
# Stiri_pozitive/9.txt  0.4693206063920298     0.5306793969913062
# Stiri_pozitive/24.txt  0.5013874092865885     0.49861259822391635
# Stiri_pozitive/13.txt  0.3677737672747029     0.6322262338322909
# Stiri_pozitive/14.txt  0.4615290092676878     0.5384710038105647
# Stiri_pozitive/2.txt  0.25680957124790266     0.7431903875299862
# Stiri_pozitive/25.txt  0.3491130894144422     0.6508869214266676
# Stiri_pozitive/5.txt  0.40419846029031986     0.5958015301642664
# Stiri_pozitive/32.txt  0.3948027032582959     0.6051972849155518
# Stiri_pozitive/4.txt  0.3231533155456151     0.6768466945430007
# Stiri_pozitive/20.txt  0.339567036580286     0.6604329704161961
# Stiri_pozitive/19.txt  0.32469087217319564     0.6753091183303677
# Stiri_pozitive/15.txt  0.4459362980498131     0.5540636861913426
# Total stiri pozitive : 35
# Corecte stiri pozitive : 29
# Acuratete Pozitive: 0.8285714285714286
#
# ---Stiri Negative---
# Stiri_negative/12.txt  0.26059858240187167     0.7394014222621917
# Stiri_negative/11.txt  0.6286767276790407     0.3713232645392418
# Stiri_negative/31.txt  0.35382939369378547     0.6461706082411954
# Stiri_negative/3.txt  0.5295177929834955     0.4704822038687785
# Stiri_negative/17.txt  0.38949816932620335     0.6105018339434759
# Stiri_negative/8.txt  0.5396450767017439     0.4603549302317142
# Stiri_negative/10.txt  0.7624003305786946     0.23759966057628557
# Stiri_negative/16.txt  0.6368161685789792     0.36318384997715436
# Stiri_negative/23.txt  0.7376432520305288     0.26235674492661554
# Stiri_negative/33.txt  0.608232765502873     0.39176721356454347
# Stiri_negative/30.txt  0.5615261474735717     0.4384738533801407
# Stiri_negative/18.txt  0.5532579906233918     0.44674200084202925
# Stiri_negative/7.txt  0.4922736659496123     0.5077263458333985
# Stiri_negative/22.txt  0.5746995382351319     0.4253004634005921
# Stiri_negative/6.txt  0.7699964108776911     0.23000357865150703
# Stiri_negative/29.txt  0.5744269270705813     0.4255730690015124
# Stiri_negative/26.txt  0.5459089401701931     0.4540910691139288
# Stiri_negative/27.txt  0.5040547271278577     0.4959452672409901
# Stiri_negative/28.txt  0.7722131719808083     0.22778680771682644
# Stiri_negative/0.txt  0.5110117456232998     0.4889882690067722
# Stiri_negative/1.txt  0.7762693345122705     0.22373065285997965
# Stiri_negative/21.txt  0.6621542099457216     0.33784578201444865
# Stiri_negative/9.txt  0.6453715144287819     0.35462848578998507
# Stiri_negative/24.txt  0.7034440230345353     0.2965559691656381
# Stiri_negative/13.txt  0.5084803874428208     0.4915196079056005
# Stiri_negative/14.txt  0.7199027601470295     0.2800972455825943
# Stiri_negative/2.txt  0.7072052765448672     0.29279473344660434
# Stiri_negative/25.txt  0.4638469324443285     0.5361530781106607
# Stiri_negative/5.txt  0.7537721616606559     0.24622784852981566
# Stiri_negative/32.txt  0.38198451998253025     0.6180154919944784
# Stiri_negative/4.txt  0.6426568905289254     0.35734310402963937
# Stiri_negative/20.txt  0.7857053097751405     0.2142947068795616
# Stiri_negative/19.txt  0.5479928810793654     0.45200712244985697
# Stiri_negative/15.txt  0.30591202763332564     0.694087964750149
# Total stiri negative : 34
# Corecte stiri negative : 27
# Acuratete negative: 0.7941176470588235
#
# Total stiri :69
# Total corecte :56
# Acuratete :0.8115942028985508
